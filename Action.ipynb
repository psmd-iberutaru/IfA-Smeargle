# %%
import astropy as ap
import astropy.io.fits as ap_fits
import astropy.modeling as ap_mod
import copy
import gc
import glob
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import scipy.optimize as sp_opt
import scipy.stats as sp_stat

import IfA_Smeargle as ifa

# %%
# Finding the data files
fits_file_list = glob.glob('./Data/SAPHIRA_Comparison_Fits/**/*.fits',recursive=True)
print(len(fits_file_list))
names = fits_file_list[0].split('\\')[-1]
print(names[:-5] + '.pdf')

print(fits_file_list[0][:-5] + '.pdf')
# Out:
# 192
# 190523_T40K_2hrdark_10.5VdetBias_down_16avg1.pdf
# ./Data/SAPHIRA_Comparison_Fits\Mk13_M06665-23\190523_T40K_2hrdark\10.5VdetBias_down\set1\190523_T40K_2hrdark_10.5VdetBias_down_16avg1.pdf

# %%
# List of figures.\n",
for filedex in fits_file_list:
    # Extract.\n",
    fits,header,data = ifa.hotel.open_fits_file(filedex)
    
    # Histogram parameters, desires 1 ADU wide bins.
    bin_list = np.arange(data.min() - 1,data.max() + 1,1)
    
    plot_hist_parameters = {}
    histogram_plot_paramters = {'bins':bin_list, 'range':None}
    plot_hist_parameters['histogram_plot_paramters'] = histogram_plot_paramters
    
    # And plot\n",
    temp_figure = ifa.hotel.plot_single_heatmap_and_histogram(data,plot_histogram_parameters=plot_hist_parameters)
    
    title = filedex.split('\\')[-1]
    temp_figure.suptitle(title)
    
    # And save the plot file. We're just saving it in the same place as the actual fits file.
    temp_figure.savefig(filedex[:-5] + '.pdf')
    
    ###

    plt.close(temp_figure)
    del temp_figure

    print(" A figure has been printed. ")
# Out:
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
#  A figure has been printed.
#  A figure has been printed.
#  A figure has been printed.
#  A figure has been printed.
#  A figure has been printed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-48d5c83ab388> in <module>
#      12
#      13     # And plot\n",
# ---> 14     temp_figure = ifa.hotel.plot_single_heatmap_and_histogram(data,plot_histogram_parameters=plot_hist_parameters)
#      15
#      16     title = filedex.split('\\')[-1]
#
# ~\Desktop\SINNOH\Research\IfA_SAPHRIA-ME1070_Array_Characterization\IfA_Smeargle\hotel\hotel_main.py in plot_single_heatmap_and_histogram(data_array, figure_subplot_parameters, plot_heatmap_parameters, plot_histogram_parameters)
#     265     # specifications.
#     266     plot_array_heatmap_image(data_array, figure_axes=ax[0], **plot_heatmap_parameters)
# --> 267     plot_array_histogram(data_array.flatten(), figure_axes=ax[1], **plot_histogram_parameters)
#     268
#     269     # The histogram feels squished unless the axes ratios are modified.
#
# ~\Desktop\SINNOH\Research\IfA_SAPHRIA-ME1070_Array_Characterization\IfA_Smeargle\hotel\hotel_main.py in plot_array_histogram(data_array, figure_axes, histogram_plot_paramters)
#     202     line_patterns = ['dotted','dashed','solid','dashed','dotted']
#     203     for linedex, colordex, patterndex in zip(mean_stddev_lines, mean_stddev_colors, line_patterns):
# --> 204         ax.axvline(x=linedex, linestyle=patterndex, color=colordex, alpha=0.75)
#     205     # Gaussian peak value horizontal line.
#     206     ax.axhline(y=gaussian_max, color='orange', alpha=0.75)
#
# ~\.conda\envs\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in axvline(self, x, ymin, ymax, **kwargs)
#     878         l = mlines.Line2D([x, x], [ymin, ymax], transform=trans, **kwargs)
#     879         self.add_line(l)
# --> 880         self.autoscale_view(scalex=scalex, scaley=False)
#     881         return l
#     882
#
# ~\.conda\envs\Anaconda\lib\site-packages\matplotlib\axes\_base.py in autoscale_view(self, tight, scalex, scaley)
#    2427             x_stickies = sum([sticky.x for sticky in stickies], [])
#    2428             y_stickies = sum([sticky.y for sticky in stickies], [])
# -> 2429             if self.get_xscale().lower() == 'log':
#    2430                 x_stickies = [xs for xs in x_stickies if xs > 0]
#    2431             if self.get_yscale().lower() == 'log':
#
# KeyboardInterrupt:
