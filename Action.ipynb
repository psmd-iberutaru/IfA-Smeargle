# %%
import astropy as ap
import astropy.io.fits as ap_fits
import astropy.modeling as ap_mod
import copy
import gc
import glob
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import numpy.ma as np_ma
import scipy as sp
import scipy.optimize as sp_opt
import scipy.stats as sp_stat

import IfA_Smeargle as ifa


# Finding the data files
fits_file_list = glob.glob('./**/Mk20_M12145-40/**/set4/*first16avg.fits',recursive=True)
print(len(fits_file_list))
names = fits_file_list[0].split('\\')[-1]
print(names[:-5] + '.pdf')

print(fits_file_list[0][:-5] + '.pdf')


counter = 0
# List of figures.\n",
for filedex in fits_file_list[counter:]:
    counter += 1

    # Extract.\n",
    fits,header,data = ifa.meta.smeargle_open_fits_file(filedex)

    # Applying hard filter.
    masks = ifa.echo.echo120_subarray_mask(data, [33,288],[0,256], return_mask=False)
    col_mask = np.array([2, 34, 66,98, 130, 162,194, 226, 258, 290]) - 1
    masks = ifa.echo.echo382_column_mask(data, col_mask, previous_mask=masks, return_mask=False)

    # Cold filtering
    masks = ifa.echo.echo_270_minimum_cut(data, 43000, previous_mask=masks, return_mask=False)
    
    final_data = ifa.echo.numpy_masked_array(data,None,masking_dictionary=masks)

    print(ifa.meta.smeargle_masked_array_min_max(final_data))
    
    # Histogram parameters, desires 1 ADU wide bins.
    bin_list = np.arange(np_ma.min(final_data) - 1,np_ma.max(final_data) + 1,100)
    hist_range = [np_ma.min(final_data),np_ma.max(final_data)]
    histogram_parameters = {'histogram_plot_paramters':{'bins':bin_list, 'range':hist_range},'fit_gaussian':False}
    
    figure = ifa.hotel.plot_single_heatmap_and_histogram(final_data,
                                      figure_subplot_parameters={'figsize':(9,3.5), 'dpi':100},
                                      plot_heatmap_parameters={},
                                      plot_histogram_parameters=histogram_parameters)

    ifa.meta.smeargle_save_figure_file(figure,filedex[:-5],filedex[:-5].split('\\')[-1])

    print(" A figure has been saved. Count {cnt}".format(cnt=counter))
# Out:
# 12
# 190411_T40K_2hrdark_10.5VdetBias_down_first16avg.pdf
# .\Data\Mk20_M12145-40\190411_T40K_2hrdark\10.5VdetBias_down\set4\190411_T40K_2hrdark_10.5VdetBias_down_first16avg.pdf
# (43000.0, 48574.0)
#  A figure has been saved. Count 1
# (43006.5, 48560.0)
#  A figure has been saved. Count 2
# (43258.0, 50738.0)
#  A figure has been saved. Count 3
# (43921.0, 50024.5)
#  A figure has been saved. Count 4
# (44262.0, 50417.0)
#  A figure has been saved. Count 5
# (43112.0, 49829.0)
#  A figure has been saved. Count 6
# (43081.0, 49309.0)
#  A figure has been saved. Count 7
# (43211.5, 49483.0)
#  A figure has been saved. Count 8
# (43009.0, 49525.0)
#  A figure has been saved. Count 9
# (43019.5, 49657.0)
#  A figure has been saved. Count 10
# (43002.0, 48776.5)
#  A figure has been saved. Count 11
# (43002.5, 48719.0)
#  A figure has been saved. Count 12

# %%
import astropy as ap
import astropy.io.fits as ap_fits
import astropy.modeling as ap_mod
import copy
import gc
import glob
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import numpy.ma as np_ma
import scipy as sp
import scipy.optimize as sp_opt
import scipy.stats as sp_stat

import IfA_Smeargle as ifa


# Finding the data files
fits_file_list = glob.glob('./**/Mk20_M12145-40/**/set4/*16avg_CDS.fits',recursive=True)
print(len(fits_file_list))
names = fits_file_list[0].split('\\')[-1]
print(names[:-5] + '.pdf')

print(fits_file_list)

mean_array = [183,183,15,15,21,21,40,40,86,86,125,125]
counter = 0
# List of figures.\n",
for filedex,meandex in zip(fits_file_list[counter:],mean_array):
    counter += 1

    # Extract.\n",
    fits,header,data = ifa.meta.smeargle_open_fits_file(filedex)

    # Applying hard filter.
    masks = ifa.echo.echo120_subarray_mask(data, [33,288],[0,256], return_mask=False)
    col_mask = np.array([2, 34, 66,98, 130, 162,194, 226, 258, 290]) - 1
    masks = ifa.echo.echo382_column_mask(data, col_mask, previous_mask=masks, return_mask=False)

    # Cold filtering
    #masks = ifa.echo.echo_270_minimum_cut(data, 43000, previous_mask=masks, return_mask=False)
    
    # Hot filtering
    masks = ifa.echo.echo_270_minimum_cut(data, meandex - 200,previous_mask=masks)
    masks = ifa.echo.echo_271_maximum_cut(data, meandex + 50, previous_mask=masks)
    
    
    final_data = ifa.echo.numpy_masked_array(data,None,masking_dictionary=masks)

    print(ifa.meta.smeargle_masked_array_min_max(final_data))
    
    # Histogram parameters, desires 1 ADU wide bins.
    bin_list = np.arange(np_ma.min(final_data) - 1,np_ma.max(final_data) + 1,1)
    hist_range = [np_ma.min(final_data),np_ma.max(final_data)]
    histogram_parameters = {'histogram_plot_paramters':{'bins':bin_list, 'range':hist_range},'fit_gaussian':False}
    
    figure = ifa.hotel.plot_single_heatmap_and_histogram(final_data,
                                      figure_subplot_parameters={'figsize':(9,3.5), 'dpi':100},
                                      plot_heatmap_parameters={},
                                      plot_histogram_parameters=histogram_parameters)

    ifa.meta.smeargle_save_figure_file(figure,filedex[:-5],filedex[:-5].split('\\')[-1])

    print(" A figure has been saved. Count {cnt}".format(cnt=counter))
# Out:
# 12
# 190411_T40K_2hrdark_10.5VdetBias_down_16avg_CDS.pdf
# ['.\\Data\\Mk20_M12145-40\\190411_T40K_2hrdark\\10.5VdetBias_down\\set4\\190411_T40K_2hrdark_10.5VdetBias_down_16avg_CDS.fits', '.\\Data\\Mk20_M12145-40\\190411_T40K_2hrdark\\10.5VdetBias_up\\set4\\190411_T40K_2hrdark_10.5VdetBias_up_16avg_CDS.fits', '.\\Data\\Mk20_M12145-40\\190411_T40K_2hrdark\\2.5VdetBias_down\\set4\\190411_T40K_2hrdark_2.5VdetBias_down_16avg_CDS.fits', '.\\Data\\Mk20_M12145-40\\190411_T40K_2hrdark\\2.5VdetBias_up\\set4\\190411_T40K_2hrdark_2.5VdetBias_up_16avg_CDS.fits', '.\\Data\\Mk20_M12145-40\\190411_T40K_2hrdark\\4.5VdetBias_down\\set4\\190411_T40K_2hrdark_4.5VdetBias_down_16avg_CDS.fits', '.\\Data\\Mk20_M12145-40\\190411_T40K_2hrdark\\4.5VdetBias_up\\set4\\190411_T40K_2hrdark_4.5VdetBias_up_16avg_CDS.fits', '.\\Data\\Mk20_M12145-40\\190411_T40K_2hrdark\\6.5VdetBias_down\\set4\\190411_T40K_2hrdark_6.5VdetBias_down_16avg_CDS.fits', '.\\Data\\Mk20_M12145-40\\190411_T40K_2hrdark\\6.5VdetBias_up\\set4\\190411_T40K_2hrdark_6.5VdetBias_up_16avg_CDS.fits', '.\\Data\\Mk20_M12145-40\\190411_T40K_2hrdark\\8.5VdetBias_down\\set4\\190411_T40K_2hrdark_8.5VdetBias_down_16avg_CDS.fits', '.\\Data\\Mk20_M12145-40\\190411_T40K_2hrdark\\8.5VdetBias_up\\set4\\190411_T40K_2hrdark_8.5VdetBias_up_16avg_CDS.fits', '.\\Data\\Mk20_M12145-40\\190411_T40K_2hrdark\\9.5VdetBias_down\\set4\\190411_T40K_2hrdark_9.5VdetBias_down_16avg_CDS.fits', '.\\Data\\Mk20_M12145-40\\190411_T40K_2hrdark\\9.5VdetBias_up\\set4\\190411_T40K_2hrdark_9.5VdetBias_up_16avg_CDS.fits']
# (-17.0, 62.0)
#  A figure has been saved. Count 1
# (-17.0, 63.5)
#  A figure has been saved. Count 2
# (-180.0, 51.0)
#  A figure has been saved. Count 3
# (-173.5, 53.5)
#  A figure has been saved. Count 4
# (-177.5, 49.5)
#  A figure has been saved. Count 5
# (-179.0, 65.5)
#  A figure has been saved. Count 6
# (-160.0, 57.0)
#  A figure has been saved. Count 7
# (-160.0, 40.5)
#  A figure has been saved. Count 8
# (-114.0, 47.5)
#  A figure has been saved. Count 9
# (-114.0, 69.0)
#  A figure has been saved. Count 10
# (-75.0, 51.5)
#  A figure has been saved. Count 11
# (-75.0, 69.5)
#  A figure has been saved. Count 12
